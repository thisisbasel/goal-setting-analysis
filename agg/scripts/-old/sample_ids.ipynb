# %%
import pandas as pd

# %%
df_bw = pd.read_csv('/Users/baselhussein/Projects/impossible_goals/brick_wall/data/cluster_features.csv')
df_cs = pd.read_csv('/Users/baselhussein/Projects/impossible_goals/crab_storage/data/cluster_features.csv

# %%
overlapping_ids = pd.merge(df_bw, df_cs, on='ID')
overlapping_ids
# Out:
#      ID  unique_goals  total_returns_x  seconds_per_goal  \
# 0     6             2                0          4.408000
# 1    12             7                9         12.821286
# 2    13             6                2         18.163833
# 3    22             2                0          7.533500
# 4    23             3                1         93.656000
# ..  ...           ...              ...               ...
# 90  242             2                0         17.183000
# 91  245             6               30         80.649333
# 92  248             5                2         15.323200
# 93  251             3                1          7.884000
# 94  252             7                7         53.342714
#
#     seconds_to_first_goal_switch_x  impasses  input_count_exploring  \
# 0                            8.816         0                     15
# 1                           17.533        17                    230
# 2                            9.300        52                    365
# ...

# %%
ids = overlapping_ids['ID']
ids
# Out:
# 0       6
# 1      12
# 2      13
# 3      22
# 4      23
#      ...
# 90    242
# 91    245
# 92    248
# 93    251
# 94    252
# Name: ID, Length: 95, dtype: int64

# %%
ids.to_csv('/Users/baselhussein/Projects/impossible_goals/agg/data/ids_evaluation.csv', index=False)
