# %% [markdown]
# ### README

# %%
# TODO

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import plotly.express as px
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv('/Users/baselhussein/Projects/impossible_goals/data/cluster_features.csv')
df
# Out:
#       ID  unique_goals  total_returns  seconds_to_first_goal_switch
# 0      2             3              4                        13.416
# 1      6             3              0                         8.816
# 2     12             8             22                        17.533
# 3     13             7              8                         9.300
# 4     22             3              0                        15.067
# ..   ...           ...            ...                           ...
# 145  252             8             35                        14.133
# 146  253             8             63                        10.450
# 147  255             7             38                         8.283
# 148  257             6             36                        25.350
# 149  258             7            104                         9.600
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Preprocessing

# %%
# Drop ID column if it's not needed for clustering
data = df.drop('ID', axis=1)

# Preprocessing: Scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Choose the number of clusters (K)
k = 7

# Initialize KMeans clustering algorithm
kmeans = KMeans(n_clusters=k, random_state=42)

# Fit the KMeans model to the scaled data
kmeans.fit(scaled_data)

# Get the cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to the DataFrame
df['Cluster'] = cluster_labels
# Out:
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df
# Out:
#       ID  unique_goals  total_returns  seconds_to_first_goal_switch  Cluster
# 0      2             3              4                        13.416        1
# 1      6             3              0                         8.816        6
# 2     12             8             22                        17.533        5
# 3     13             7              8                         9.300        0
# 4     22             3              0                        15.067        1
# ..   ...           ...            ...                           ...      ...
# 145  252             8             35                        14.133        2
# 146  253             8             63                        10.450        2
# 147  255             7             38                         8.283        2
# 148  257             6             36                        25.350        5
# 149  258             7            104                         9.600        4
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Visualization

# %%
# Visualize the clusters
fig = px.scatter_matrix(df, color='Cluster', title='Clustering Visualization')
fig.update_traces(diagonal_visible=False)  # Hide histograms on the diagonal
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/t1/sdbl9_cd061431ynt1cns5hh0000gn/T/ipykernel_5340/4202174289.py in ?()
#       1 # Visualize the clusters
# ----> 2 fig = px.scatter_matrix(df, color='Cluster', title='Clustering Visualization')
#       3 fig.update_traces(diagonal_visible=False)  # Hide histograms on the diagonal
#       4 fig.show()
#
# ~/anaconda3/lib/python3.11/site-packages/plotly/express/_chart_types.py in ?(data_frame, dimensions, color, symbol, size, hover_name, hover_data, custom_data, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, title, template, width, height)
#    1388     represented by a multiple symbol marks, one in each cell of a grid of
#    1389     2D scatter plots, which plot each pair of `dimensions` against each
#    1390     other.
#    1391     """
# -> 1392     return make_figure(
#    1393         args=locals(), constructor=go.Splom, layout_patch=dict(dragmode="select")
#    1394     )
#
# ~/anaconda3/lib/python3.11/site-packages/plotly/express/_core.py in ?(args, constructor, trace_patch, layout_patch)
#    2163                     group[var] = group[var] / group_sum
#    2164                 elif args["ecdfnorm"] == "percent":
#    2165                     group[var] = 100.0 * group[var] / group_sum
#    2166
# -> 2167             patch, fit_results = make_trace_kwargs(
#    2168                 args, trace_spec, group, mapping_labels.copy(), sizeref
#    2169             )
#    2170             trace.update(patch)
#
# ~/anaconda3/lib/python3.11/site-packages/plotly/express/_core.py in ?(args, trace_spec, trace_data, mapping_labels, sizeref)
#     277         attr_label = get_decorated_label(args, attr_value, attr_name)
#     278         if attr_name == "dimensions":
#     279             dims = [
#     280                 (name, column)
# --> 281                 for (name, column) in trace_data.iteritems()
#     282                 if ((not attr_value) or (name in attr_value))
#     283                 and (
#     284                     trace_spec.constructor != go.Parcoords
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'iteritems'

# %% [markdown]
# ### Evaluation

# %%
# Evaluate the clustering
silhouette = silhouette_score(scaled_data, cluster_labels)
db_index = davies_bouldin_score(scaled_data, cluster_labels)

print(f"Silhouette Score: {silhouette}")
print(f"Davies-Bouldin Index: {db_index}")
# Out:
# Silhouette Score: 0.45942534603886204
# Davies-Bouldin Index: 0.8558429746437105

# %%
# Define range of k values
k_values = range(2, 15)  # Adjust range as needed

# Store silhouette scores
silhouette_scores = []

for k in k_values:
    # Initialize KMeans clustering algorithm
    kmeans = KMeans(n_clusters=k, random_state=42)
    
    # Fit the KMeans model to the scaled data
    kmeans.fit(scaled_data)
    
    # Get the cluster labels
    cluster_labels = kmeans.labels_
    
    # Calculate silhouette score
    silhouette = silhouette_score(scaled_data, cluster_labels)
    silhouette_scores.append(silhouette)

# Print summary of silhouette scores
print("Silhouette Scores:")
for k, score in zip(k_values, silhouette_scores):
    print(f"Number of Clusters (k = {k}): Silhouette Score = {score}")
# Out:
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Silhouette Scores:
# Number of Clusters (k = 2): Silhouette Score = 0.35677411879613735
# Number of Clusters (k = 3): Silhouette Score = 0.4180767484593502
# Number of Clusters (k = 4): Silhouette Score = 0.5239056590050424
# Number of Clusters (k = 5): Silhouette Score = 0.5287982791379662
# Number of Clusters (k = 6): Silhouette Score = 0.5463621283174908
# Number of Clusters (k = 7): Silhouette Score = 0.45942534603886204
# Number of Clusters (k = 8): Silhouette Score = 0.4528823093701009
# Number of Clusters (k = 9): Silhouette Score = 0.42619315972119365
# Number of Clusters (k = 10): Silhouette Score = 0.4274670348699983
# Number of Clusters (k = 11): Silhouette Score = 0.3599476093409152
# Number of Clusters (k = 12): Silhouette Score = 0.36872044904109347
# Number of Clusters (k = 13): Silhouette Score = 0.3670615033147275
# Number of Clusters (k = 14): Silhouette Score = 0.3754237235014152
# /Users/baselhussein/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
