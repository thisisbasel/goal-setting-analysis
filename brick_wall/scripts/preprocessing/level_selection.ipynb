# %%
# This file takes in the complete pps logdata file and filters out level "Brick Wall"

# %%
import pandas as pd

# %%
# Define file paths

pps_logdata = "/Users/baselhussein/Projects/pps/data/Longform.csv"
output_path = "/Users/baselhussein/Projects/impossible_goals/data/brick_wall.csv"

# %%
df = pd.read_csv(pps_logdata)

# %%
# df.head()
# Out:
#     ID Session_timestamp Level_timestamp Event_type          Event  \
# 0  100         0:0:0:000       0:0:0:000      event  session_start
# 1  100         0:0:9:583       0:0:0:000      event          start
# 2  100         0:0:9:583       0:0:0:000      event    init_object
# 3  100         0:0:9:583       0:0:0:000      event    init_object
# 4  100         0:0:9:583       0:0:0:000      event    init_object
#
#                 Level              Details   filename    epoch_time  \
# 0                 NaN  26/01/2022 18:02:52  100_0.txt  1.643220e+12
# 1  0level:baba is you                  NaN  100_0.txt  1.643220e+12
# 2  0level:baba is you       text_baba:12:7  100_0.txt  1.643220e+12
# 3  0level:baba is you            wall:12:9  100_0.txt  1.643220e+12
# 4  0level:baba is you           tile:12:10  100_0.txt  1.643220e+12
#
#    object_orientation  x_coordinate  y_coordinate    objects  Session_number  \
# ...

# %%
levels = df['Level'].unique()

# %%
# print(levels)

# %%
brick_wall = df[df['Level'] == '93level:brick wall']

# %%
# brick_wall.head()

# %%
brick_wall.to_csv(output_path, index=False)
